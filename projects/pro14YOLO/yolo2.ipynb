# %% [markdown]
# <a href="https://colab.research.google.com/github/ldfha/RotemAI/blob/main/projects/pro14YOLO/yolo2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Precision, Recall, mAP 확인하기
# !unzip aquarium_dataset.zip
# Out:
# Archive:  aquarium_dataset.zip
#    creating: aquarium_dataset/
#   inflating: aquarium_dataset/data.yaml
#   inflating: aquarium_dataset/README.dataset.txt
#   inflating: aquarium_dataset/README.roboflow.txt
#    creating: aquarium_dataset/test/
#    creating: aquarium_dataset/test/images/
#   inflating: aquarium_dataset/test/images/IMG_2289_jpeg_jpg.rf.454853cd2293ea7c52dc52e02f1a0138.jpg
#   inflating: aquarium_dataset/test/images/IMG_2301_jpeg_jpg.rf.3896af7d1507e001ebb005c9f74fc4ab.jpg
#   inflating: aquarium_dataset/test/images/IMG_2319_jpeg_jpg.rf.699258057d3128d0f8200dbf6f3b92bb.jpg
#   inflating: aquarium_dataset/test/images/IMG_2347_jpeg_jpg.rf.6a8f94e254e2ae26d1a37bfd79cee911.jpg
#   inflating: aquarium_dataset/test/images/IMG_2354_jpeg_jpg.rf.0db812e028c3a47698df735becc1a1e4.jpg
#   inflating: aquarium_dataset/test/images/IMG_2371_jpeg_jpg.rf.41b966a3ddb7988b27da6d8653200aa7.jpg
# ...

# %%
# !pip install ultralytics opencv-python
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 53.9 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

model = YOLO('yolo11n.pt')

metrics = model.val(
    data = r'aquarium_dataset/data.yaml',
    imgsz=640
)

print('Precision :', metrics.box.mp)
print('Recall :', metrics.box.mr)
print('mAP50 :', metrics.box.map50)
print('mAP50-95 :', metrics.box.map)
# Precision : 0.02657698596149982
# Recall : 0.0926869970987618
# mAP50 : 0.01988449241985285         IoU 0.5 기준에서 계산한 AP
# mAP50-95 : 0.011751987471109789     mAP50 보다 더 엄격한 기준
# 점수가 낮은 이유는 백본이 coco dataset(라벨 80개),
# aquarium dataset은 라벨(['fish', 'jellyfish', 'penguin', 'puffin', 'shark', 'starfish', 'stingray']) 7개
# Out:
# Ultralytics 8.4.51 🚀 Python-3.12.13 torch-2.10.0+cpu CPU (AMD EPYC 7B12)
# YOLO11n summary (fused): 100 layers, 2,616,248 parameters, 0 gradients, 6.5 GFLOPs
# ...
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 28.5±25.9 MB/s, size: 80.2 KB)
# val: Scanning /content/aquarium_dataset/valid/labels... 127 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 127/127 361.9it/s 0.4s
# val: New cache created: /content/aquarium_dataset/valid/labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 3.6s/it 28.7s
#                    all        127        909     0.0266     0.0927     0.0199     0.0118
#                 person         63        459     0.0481      0.218       0.02    0.00962
#                bicycle          9        155          0          0          0          0
#                    car         17        104      0.026     0.0673     0.0018   0.000596
# ...
